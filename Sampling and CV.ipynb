# %%
# Loading Libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Dataframe
df = pd.read_csv('Data.csv')
df.head()
# Out:
#    Unnamed: 0  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        6607       1              0        0           1       1
# 1        2598       0              0        0           0       7
# 2        2345       0              0        0           1       4
# 3        4093       0              0        0           0      29
# 4         693       0              0        0           0       3
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                1               0  ...
# 2             1              0                2               1  ...
# 3             1              2                1               0  ...
# 4             1              2                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
# Drop unnecessary columns/features
df.drop('Unnamed: 0',axis=1, inplace=True)
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        0           1       1             0
# 1       0              0        0           0       7             1
# 2       0              0        0           1       4             1
# 3       0              0        0           0      29             1
# 4       0              0        0           0       3             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             0
# 1              0                1               0             0
# 2              0                2               1             1
# 3              2                1               0             0
# 4              2                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.shape
# Out:
# (5282, 20)

# %%
# Count of Unique Values
df.Churn.value_counts()
# Out:
# 0    3892
# 1    1390
# Name: Churn, dtype: int64

# %%
# No value percentage
1390 / (3892+1390)
# Out:
# 0.2631578947368421

# %%
# Summary of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5282 entries, 0 to 5281
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            5282 non-null   int64
#  1   SeniorCitizen     5282 non-null   int64
#  2   Partner           5282 non-null   int64
#  3   Dependents        5282 non-null   int64
#  4   tenure            5282 non-null   int64
#  5   PhoneService      5282 non-null   int64
#  6   MultipleLines     5282 non-null   int64
#  7   InternetService   5282 non-null   int64
#  8   OnlineSecurity    5282 non-null   int64
#  9   OnlineBackup      5282 non-null   int64
#  10  DeviceProtection  5282 non-null   int64
#  11  TechSupport       5282 non-null   int64
#  12  StreamingTV       5282 non-null   int64
#  13  StreamingMovies   5282 non-null   int64
#  14  Contract          5282 non-null   int64
#  15  PaperlessBilling  5282 non-null   int64
# ...

# %% [markdown]
# ## Analysis the dataset using seaborn / matplotlib / scatter

# %%
# Correlation between features
df.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.005691 -0.010143    0.011058  0.001303
# SeniorCitizen    -0.005691       1.000000  0.016648   -0.211271  0.006176
# Partner          -0.010143       0.016648  1.000000    0.447629  0.382432
# Dependents        0.011058      -0.211271  0.447629    1.000000  0.162933
# tenure            0.001303       0.006176  0.382432    0.162933  1.000000
# PhoneService     -0.009706       0.000581  0.031578   -0.005830  0.005912
# MultipleLines    -0.000430       0.129040  0.151068   -0.020722  0.354790
# InternetService  -0.005294      -0.040186  0.007205    0.041972 -0.032037
# OnlineSecurity   -0.020189      -0.129719  0.159928    0.157262  0.325451
# OnlineBackup     -0.025773      -0.012166  0.166939    0.095640  0.371342
# DeviceProtection -0.009305      -0.015922  0.168815    0.076783  0.369331
# TechSupport      -0.010619      -0.151078  0.132582    0.137274  0.326993
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df.corr(),annot=True)

# %%
sns.pairplot(df)

# %%
sns.countplot(df.gender,hue='Churn',data=df)

# %%
sns.countplot(df['SeniorCitizen'],hue=df.Churn)

# %%
sns.countplot(df.Dependents,hue=df.Churn)

# %%
sns.countplot(df.PhoneService,hue=df.Churn)

# %%
sns.countplot(df['InternetService'],hue=df.Churn)

# %%
sns.countplot(df.TechSupport,hue="Churn" , data=df)

# %%
sns.barplot(df.Churn,df.TechSupport,hue='gender',data=df)

# %%
sns.catplot(x="Churn", y="MonthlyCharges",hue="gender", data=df)

# %%
x = df.drop('Churn',axis=1)
y = df.Churn

# %%
x.shape
# Out:
# (5282, 19)

# %%
y.value_counts()
# Out:
# 0    3892
# 1    1390
# Name: Churn, dtype: int64

# %% [markdown]
# # ML model and evaluating model by cross validation before sampling

# %% [markdown]
# ## Hold out Cross Validation

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest=train_test_split(x,y, test_size=0.3, random_state=42)

# %%
xtrain.shape
# Out:
# (3697, 19)

# %%
ytrain.shape
# Out:
# (3697,)

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
score_dtc = dtc.score(xtest,ytest)

# %%
score_dtc
# Out:
# 0.7129337539432177

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
score_rfc = rfc.score(xtest,ytest)

# %%
score_rfc
# Out:
# 0.7899053627760252

# %% [markdown]
# ### Xtream Gradient boosting (XGBoost) Classifier

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
xgbc = XGBClassifier()

# %%
xgbc.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
score_xgbc = xgbc.score(xtest,ytest)

# %%
score_xgbc
# Out:
# 0.7728706624605678

# %% [markdown]
# ### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
abc = AdaBoostClassifier()

# %%
abc.fit(xtrain,ytrain)
# Out:
# AdaBoostClassifier()

# %%
score_abc = abc.score(xtest,ytest)

# %%
score_abc
# Out:
# 0.7867507886435331

# %% [markdown]
# ### K-Nearest Neighbour (KNN) Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knnc = KNeighborsClassifier()

# %%
knnc.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
score_knnc = knnc.score(xtest,ytest)

# %%
score_knnc
# Out:
# 0.7488958990536277

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lrc = LogisticRegression()

# %%
lrc.fit(xtrain,ytrain)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
score_lrc = lrc.score(xtest,ytest)

# %%
score_lrc
# Out:
# 0.7886435331230284

# %% [markdown]
# ## Comparison

# %%
cdf = pd.DataFrame([['Decision Tree',score_dtc],['Random Forest',score_rfc],['XGBoost',score_xgbc],['Ada Boost',score_abc],['K-Nearest Neighbor',score_knnc],['Logistic Regression',score_lrc]],columns=['Classifier', 'Accuracy'])
cdf
# Out:
#             Classifier  Accuracy
# 0        Decision Tree  0.712934
# 1        Random Forest  0.789905
# 2              XGBoost  0.772871
# 3            Ada Boost  0.786751
# 4   K-Nearest Neighbor  0.748896
# 5  Logistic Regression  0.788644

# %%
sns.barplot(cdf.Accuracy,cdf.Classifier)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
from sklearn.model_selection import KFold, cross_val_score
kf = KFold(n_splits=5) #each fold will contain 20% data

# %%
result_kf = cross_val_score(lrc, x, y,cv=kf)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
result_kf
# Out:
# array([0.81740776, 0.78807947, 0.7907197 , 0.77556818, 0.80681818])

# %%
result_kf.min()
# Out:
# 0.7755681818181818

# %%
result_kf.max()
# Out:
# 0.8174077578051088

# %% [markdown]
# ### Stratified k-fold Cross Validation

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold()

# %%
result_skf = cross_val_score(lrc, x, y,cv=skf)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
result_skf
# Out:
# array([0.81078524, 0.79564806, 0.79166667, 0.77840909, 0.79734848])

# %%
result_skf.max()
# Out:
# 0.8107852412488175

# %%
result_skf.min()
# Out:
# 0.7784090909090909

# %% [markdown]
# ### Leave One Out Cross Validation(LOOC)

# %%
#from sklearn.model_selection import LeaveOneOut
#loo = LeaveOneOut()
#result = cross_val_score(lrc,X,y,cv=loo)
#result
#result.mean()

# %% [markdown]
# # sampling on given dataset and Create ML model and evaluating model by cross validation again (after sampling)

# %%
y.value_counts()
# Out:
# 0    3892
# 1    1390
# Name: Churn, dtype: int64

# %%
x.shape
# Out:
# (5282, 19)

# %% [markdown]
# ## Sampling

# %% [markdown]
# ## S1. CROSS Validation with Synthetic Minority Oversampling Technique (SMOTETomek)

# %%
pip install imblearn
# Out:
# ...
#   Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# ...
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# ...
#   Using cached imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.combine import SMOTETomek
smt = SMOTETomek()

# %%
x_smt, y_smt = smt.fit_resample(x,y)

# %%
x_smt.shape
# Out:
# (7190, 19)

# %%
y_smt.value_counts()
# Out:
# 1    3595
# 0    3595
# Name: Churn, dtype: int64

# %% [markdown]
# ## Hold out cross validation

# %%
x_smt_train,x_smt_test,y_smt_train,y_smt_test = train_test_split(x_smt,y_smt,train_size=.7,random_state=42)

# %%
x_smt_train.shape
# Out:
# (5033, 19)

# %%
x_smt_test.shape
# Out:
# (2157, 19)

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc_smt = DecisionTreeClassifier()
dtc_smt.fit(x_smt_train,y_smt_train)
# Out:
# DecisionTreeClassifier()

# %%
score_dtc_smt = dtc_smt.score(x_smt_test,y_smt_test)

# %%
score_dtc_smt
# Out:
# 0.8191933240611962

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc_smt = RandomForestClassifier()
rfc_smt.fit(x_smt_train,y_smt_train)
# Out:
# RandomForestClassifier()

# %%
score_rfc_smt = rfc_smt.score(x_smt_test,y_smt_test)
score_rfc_smt
# Out:
# 0.8687992582290218

# %% [markdown]
# ### XGBoost Classifier

# %%
xgbc_smt = XGBClassifier()
xgbc_smt.fit(x_smt_train,y_smt_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
score_xgbc_smt = xgbc_smt.score(x_smt_test,y_smt_test)
score_xgbc_smt
# Out:
# 0.866481223922114

# %% [markdown]
# ### Ada Boost classifier

# %%
abc_smt = AdaBoostClassifier()
abc_smt.fit(x_smt_train,y_smt_train)
# Out:
# AdaBoostClassifier()

# %%
score_abc_smt = abc_smt.score(x_smt_test,y_smt_test)
score_abc_smt
# Out:
# 0.8437644877144181

# %% [markdown]
# ### KNN Classifier

# %%
knnc_smt = KNeighborsClassifier()
knnc_smt.fit(x_smt_train,y_smt_train)
# Out:
# KNeighborsClassifier()

# %%
score_knnc_smt = knnc_smt.score(x_smt_test,y_smt_test)
score_knnc_smt
# Out:
# 0.799721835883171

# %% [markdown]
# ### Logistic Regression

# %%
lrc_smt = LogisticRegression()
lrc_smt.fit(x_smt_train,y_smt_train)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
score_lrc_smt = lrc_smt.score(x_smt_test,y_smt_test)
score_lrc_smt
# Out:
# 0.8293926750115902

# %% [markdown]
# ### Comparison

# %%
df_smt = pd.DataFrame([['Decision Tree (SMOTETomek)',score_dtc_smt],['Random Forest (SMOTETomek)',score_rfc_smt],['XGBoost (SMOTETomek)',score_xgbc_smt],['Ada Boost (SMOTETomek)',score_abc_smt],['K-Nearest Neighbor (SMOTETomek)',score_knnc_smt],['Logistic Regression (SMOTETomek)',score_lrc_smt]],columns=['Classifier', 'Accuracy'])
df_smt
# Out:
#                          Classifier  Accuracy
# 0        Decision Tree (SMOTETomek)  0.819193
# 1        Random Forest (SMOTETomek)  0.868799
# 2              XGBoost (SMOTETomek)  0.866481
# 3            Ada Boost (SMOTETomek)  0.843764
# 4   K-Nearest Neighbor (SMOTETomek)  0.799722
# 5  Logistic Regression (SMOTETomek)  0.829393

# %%
sns.barplot(df_smt.Accuracy,df_smt.Classifier])

# %% [markdown]
# ### K-Fold Cross Validation

# %%
kf_smt = KFold(n_splits=5)
result_kf_smt = cross_val_score(rfc_smt, x_smt, y_smt,cv=kf_smt)
result_kf_smt
# Out:
# array([0.80667594, 0.81641168, 0.79763561, 0.91655076, 0.95201669])

# %%
result_kf.min()
# Out:
# 0.7755681818181818

# %%
result_kf.max()
# Out:
# 0.8174077578051088

# %% [markdown]
# ### Stratified k-fold Cross Validation

# %%
skf_smt = StratifiedKFold()
result_skf_smt = cross_val_score(rfc_smt, x_smt, y_smt,cv=skf_smt)
result_skf_smt
# Out:
# array([0.73504868, 0.80945758, 0.91655076, 0.89916551, 0.90403338])

# %%
result_skf_smt.max()
# Out:
# 0.9165507649513213

# %%
result_skf_smt.min()
# Out:
# 0.7350486787204451

# %% [markdown]
# ### Leave-One-Out-Cross-Validation(LOOC)

# %%
#loo_smt = LeaveOneOut()
#result_smt = cross_val_score(rfc_smt,x_smt,y_smt,cv=loo_smt)
#result_smt
#result_smt.mean()

# %% [markdown]
# # S2. Cross Validation with Near Miss

# %%
from imblearn.under_sampling import NearMiss
nm = NearMiss()

# %%
x_nm,y_nm = nm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    3892
# 1    1390
# Name: Churn, dtype: int64

# %%
y_nm.value_counts()
# Out:
# 1    1390
# 0    1390
# Name: Churn, dtype: int64

# %% [markdown]
# ## Hold out Cross Validation

# %%
x_nm_train,x_nm_test,y_nm_train,y_nm_test = train_test_split(x_nm,y_nm,train_size=.7,random_state=42)

# %%
x_nm_train.shape
# Out:
# (1945, 19)

# %%
x_nm_test.shape
# Out:
# (835, 19)

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc_nm = DecisionTreeClassifier()
dtc_nm.fit(x_nm_train,y_nm_train)
# Out:
# DecisionTreeClassifier()

# %%
score_dtc_nm = dtc_nm.score(x_nm_test,y_nm_test)

# %%
score_dtc_nm
# Out:
# 0.629940119760479

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc_nm = RandomForestClassifier()
rfc_nm.fit(x_nm_train,y_nm_train)
# Out:
# RandomForestClassifier()

# %%
score_rfc_nm = rfc_nm.score(x_nm_test,y_nm_test)
score_rfc_nm
# Out:
# 0.6574850299401198

# %% [markdown]
# ### XGBoost Classifier

# %%
xgbc_nm = XGBClassifier()
xgbc_nm.fit(x_nm_train,y_nm_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
score_xgbc_nm = xgbc_nm.score(x_nm_test,y_nm_test)
score_xgbc_nm
# Out:
# 0.6730538922155689

# %% [markdown]
# ### Ada Boost classifier

# %%
abc_nm = AdaBoostClassifier()
abc_nm.fit(x_nm_train,y_nm_train)
# Out:
# AdaBoostClassifier()

# %%
score_abc_nm = abc_nm.score(x_nm_test,y_nm_test)
score_abc_nm
# Out:
# 0.6778443113772455

# %% [markdown]
# ### KNN Classifier

# %%
knnc_nm = KNeighborsClassifier()
knnc_nm.fit(x_nm_train,y_nm_train)
# Out:
# KNeighborsClassifier()

# %%
score_knnc_nm = knnc_nm.score(x_nm_test,y_nm_test)
score_knnc_nm
# Out:
# 0.578443113772455

# %% [markdown]
# ### Logistic Regression

# %%
lrc_nm = LogisticRegression()
lrc_nm.fit(x_nm_train,y_nm_train)
# Out:
# LogisticRegression()

# %%
score_lrc_nm = lrc_nm.score(x_nm_test,y_nm_test)
score_lrc_nm
# Out:
# 0.6634730538922156

# %% [markdown]
# ### Comparison

# %%
df_nm = pd.DataFrame([['Decision Tree (Near Miss)',score_dtc_nm],['Random Forest (Near Miss)',score_rfc_nm],['XGBoost (Near Miss)',score_xgbc_nm],['Ada Boost (Near Miss)',score_abc_nm],['K-Nearest Neighbor (Near Miss)',score_knnc_nm],['Logistic Regression (Near Miss)',score_lrc_nm]],columns=['Classifier', 'Accuracy'])
df_nm
# Out:
#                         Classifier  Accuracy
# 0        Decision Tree (Near Miss)  0.629940
# 1        Random Forest (Near Miss)  0.657485
# 2              XGBoost (Near Miss)  0.673054
# 3            Ada Boost (Near Miss)  0.677844
# 4   K-Nearest Neighbor (Near Miss)  0.578443
# 5  Logistic Regression (Near Miss)  0.663473

# %%
sns.barplot(df_nm.Accuracy,df_nm.Classifier)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
kf_nm = KFold(n_splits=5)
result_kf_nm = cross_val_score(abc_nm, x_nm, y_nm,cv=kf_nm)
result_kf_nm
# Out:
# array([0.26978417, 0.4676259 , 0.72841727, 0.52697842, 0.47661871])

# %%
result_kf_nm.min()
# Out:
# 0.2697841726618705

# %%
result_kf_nm.max()
# Out:
# 0.7284172661870504

# %% [markdown]
# ### Stratified k-fold Cross Validation

# %%
skf_nm = StratifiedKFold()
result_skf_nm = cross_val_score(abc_nm, x_nm, y_nm,cv=skf_nm)
result_skf_nm
# Out:
# array([0.50179856, 0.64568345, 0.67625899, 0.69064748, 0.69244604])

# %%
result_skf_nm.min()
# Out:
# 0.5017985611510791

# %%
result_skf_nm.max()
# Out:
# 0.6924460431654677

# %% [markdown]
# ### Leave-One-Out-Cross-Validation(LOOC)

# %%
#loo_nm = LeaveOneOut()
#result_nm = cross_val_score(abc_nm,x_nm,y_nm,cv=loo_nm)
#result_nm
#result_nm.mean()

# %% [markdown]
# # S3. Cross Validation with Random Over Sampler

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()

# %%
x_ros,y_ros = ros.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    3892
# 1    1390
# Name: Churn, dtype: int64

# %%
y_ros.value_counts()
# Out:
# 1    3892
# 0    3892
# Name: Churn, dtype: int64

# %% [markdown]
# ### Hold Out Cross Validation

# %%
x_ros_train,x_ros_test,y_ros_train,y_ros_test = train_test_split(x_ros,y_ros,train_size=.7,random_state=42)

# %%
x_ros_train.shape
# Out:
# (5448, 19)

# %%
# Out:
# (2336, 19)

# %% [markdown]
# ### Decision Tree Classifier

# %%
dtc_ros = DecisionTreeClassifier()
dtc_ros.fit(x_ros_train,y_ros_train)
# Out:
# DecisionTreeClassifier()

# %%
score_dtc_ros = dtc_ros.score(x_ros_test,y_ros_test)
score_dtc_ros
# Out:
# 0.8608732876712328

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc_ros = RandomForestClassifier()
rfc_ros.fit(x_ros_train,y_ros_train)
# Out:
# RandomForestClassifier()

# %%
score_rfc_ros = rfc_ros.score(x_ros_test,y_ros_test)
score_rfc_ros
# Out:
# 0.875

# %% [markdown]
# ### XGBoost Classifier

# %%
xgbc_ros = XGBClassifier()
xgbc_ros.fit(x_ros_train,y_ros_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
score_xgbc_ros = xgbc_ros.score(x_ros_test,y_ros_test)
score_xgbc_ros
# Out:
# 0.8441780821917808

# %% [markdown]
# ### Ada Boost classifier

# %%
abc_ros = AdaBoostClassifier()
abc_ros.fit(x_ros_train,y_ros_train)
# Out:
# AdaBoostClassifier()

# %%
score_abc_ros = abc_ros.score(x_ros_test,y_ros_test)
score_abc_ros
# Out:
# 0.7551369863013698

# %% [markdown]
# ### KNN Classifier

# %%
knnc_ros = KNeighborsClassifier()
knnc_ros.fit(x_ros_train,y_ros_train)
# Out:
# KNeighborsClassifier()

# %%
score_knnc_ros = knnc_ros.score(x_ros_test,y_ros_test)
score_knnc_ros
# Out:
# 0.7277397260273972

# %% [markdown]
# ### Logistic Regression

# %%
lrc_ros = LogisticRegression()
lrc_ros.fit(x_ros_train,y_ros_train)
# Out:
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
score_lrc_ros = lrc_ros.score(x_ros_test,y_ros_test)
score_lrc_ros
# Out:
# 0.7478595890410958

# %% [markdown]
# ### Comparison

# %%
df_ros = pd.DataFrame([['Decision Tree (Random Over Sampler)',score_dtc_ros],['Random Forest (Random Over Sampler)',score_rfc_ros],['XGBoost (Random Over Sampler)',score_xgbc_ros],['Ada Boost (Random Over Sampler)',score_abc_ros],['K-Nearest Neighbor (Random Over Sampler)',score_knnc_ros],['Logistic Regression (Random Over Sampler)',score_lrc_ros]],columns=['Classifier', 'Accuracy'])
df_ros
# Out:
#                                   Classifier  Accuracy
# 0        Decision Tree (Random Over Sampler)  0.860873
# 1        Random Forest (Random Over Sampler)  0.875000
# 2              XGBoost (Random Over Sampler)  0.844178
# 3            Ada Boost (Random Over Sampler)  0.755137
# 4   K-Nearest Neighbor (Random Over Sampler)  0.727740
# 5  Logistic Regression (Random Over Sampler)  0.747860

# %%
sns.barplot(df_ros.Accuracy,df_ros.Classifier)

# %% [markdown]
# ### K-Fold Cross Validation

# %%
kf_ros = KFold(n_splits=5)
result_kf_ros = cross_val_score(abc_ros, x_ros, y_ros,cv=kf_ros)
result_kf_ros
# Out:
# array([0.72254335, 0.72575466, 0.71612075, 0.77007065, 0.68187661])

# %%
result_kf_ros.min()
# Out:
# 0.6818766066838047

# %%
result_kf_ros.max()
# Out:
# 0.7700706486833655

# %% [markdown]
# ### Stratified k-fold Cross Validation

# %%
skf_ros = StratifiedKFold()
result_skf_ros = cross_val_score(abc_ros, x_ros, y_ros,cv=skf_ros)
result_skf_ros
# Out:
# array([0.77520873, 0.77135517, 0.77777778, 0.7495183 , 0.77763496])

# %%
result_skf_ros.min()
# Out:
# 0.7495183044315993

# %%
result_skf_ros.max()
# Out:
# 0.7777777777777778

# %% [markdown]
# ### Leave-One-Out-Cross-Validation(LOOC)

# %%
#loo_ros = LeaveOneOut()
#result_ros = cross_val_score(abc_ros,x_ros,y_ros,cv=loo_ros)
#result_ros
#result_ros.mean()

# %% [markdown]
# # Evaluate all results

# %%
df_compare = pd.concat([cdf,df_smt,df_nm,df_ros])
df_compare
# Out:
#                                   Classifier  Accuracy
# 0                              Decision Tree  0.712934
# 1                              Random Forest  0.789905
# 2                                    XGBoost  0.772871
# 3                                  Ada Boost  0.786751
# 4                         K-Nearest Neighbor  0.748896
# 5                        Logistic Regression  0.788644
# 0                 Decision Tree (SMOTETomek)  0.819193
# 1                 Random Forest (SMOTETomek)  0.868799
# 2                       XGBoost (SMOTETomek)  0.866481
# 3                     Ada Boost (SMOTETomek)  0.843764
# 4            K-Nearest Neighbor (SMOTETomek)  0.799722
# 5           Logistic Regression (SMOTETomek)  0.829393
# 0                  Decision Tree (Near Miss)  0.629940
# 1                  Random Forest (Near Miss)  0.657485
# 2                        XGBoost (Near Miss)  0.673054
# 3                      Ada Boost (Near Miss)  0.677844
# ...

# %%
df_compare.reset_index(drop=True,inplace=True)

# %%
df_compare
# Out:
#                                    Classifier  Accuracy
# 0                               Decision Tree  0.712934
# 1                               Random Forest  0.789905
# 2                                     XGBoost  0.772871
# 3                                   Ada Boost  0.786751
# 4                          K-Nearest Neighbor  0.748896
# 5                         Logistic Regression  0.788644
# 6                  Decision Tree (SMOTETomek)  0.819193
# 7                  Random Forest (SMOTETomek)  0.868799
# 8                        XGBoost (SMOTETomek)  0.866481
# 9                      Ada Boost (SMOTETomek)  0.843764
# 10            K-Nearest Neighbor (SMOTETomek)  0.799722
# 11           Logistic Regression (SMOTETomek)  0.829393
# 12                  Decision Tree (Near Miss)  0.629940
# 13                  Random Forest (Near Miss)  0.657485
# 14                        XGBoost (Near Miss)  0.673054
# 15                      Ada Boost (Near Miss)  0.677844
# ...

# %%
df_compare.Accuracy.max()
# Out:
# 0.875

# %%
# Locating Maximum row values
df_compare.loc[df_compare['Accuracy'].idxmax()]
# Out:
# Classifier    Random Forest (Random Over Sampler)
# Accuracy                                    0.875
# Name: 19, dtype: object

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Accuracy',y='Classifier',data=df_compare)
